# %%
class Spotify:
    def __init__(self, OS, player):
        self.OS=OS
        self.player=player
    def Marionette(listBCEFCEFCE):
        listc = []
        listc = Karnesos
        Karnesos.update('Midrenios')
print("Install and Initiate Spotify OS in Tablet PC")
