# %%
class AI:
    def __init__(self, OS):
        self.OS=OS
    def Artoriensis(MethodB):
        listE = []
        listE = APCEF
        APCEF.append('BFCE')
        APCEF.append('GHECFEC')
print("Install and Initiate AI OS in this notebook computer.")
